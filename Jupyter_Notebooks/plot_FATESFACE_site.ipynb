# %% [markdown]
# ## Bharat Sharma
#
# Oct 31, 2022 onward...
# bharat.sharma.neu@gmail.com
#
# Aim: to plot site level plots of the data

# %%
# libraries
import os
import pandas as pd
import pyreadr # to read .rds files

# %%
# paths [model]
wd_obs  =  '/Users/ud4/Documents/FATESMDS/Models/obs_data'
root    =  '/Users/ud4/Documents/FATESMDS/Models/FATES/runs/FACE/'
wd_src  =  f'{root}FATESFACE_analysis' 
moddate_ens = '221031'
moddate     = '221031'
wdo         = f'{root}{moddate}/plots'

# %%
# paths [obs]
# Preparing the obs files
# reading the files
df_co2 = pd.read_csv(f'{wd_obs}/site_annual_CO2.csv')
# replacing the original abreviations of 'a' and 'e' to AMB and ELE; ambient and elevated
df_co2['co2'] = df_co2['co2'].replace({'a':'AMB','e':'ELE'})
# renaming year to year
df_co2= df_co2.rename(columns={'year':'YEAR'})

# %%
# reading RDS data

ifile  = 'OBS_ax.rds'
df_obs = pyreadr.read_r(f'{wd_obs}/{ifile}')
df_obs = df_obs[None] # same as pandas dataframe

# %%
df_obs
# Out:
#             YEAR  DOY  CO2  PPT  PAR   AT   ST  VPD   SW NDEP  ... CL_herb  \
# rownames                                                       ...
# 1         1998.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...     NaN
# 2         1999.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...     NaN
# 3         2000.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...     NaN
# 4         2001.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...     NaN
# 5         2002.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...     NaN
# ...          ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...     ...
# 501       2009.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...     NaN
# 511       2010.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...     NaN
# 521       2011.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...     NaN
# 531       2012.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...     NaN
# 541       2013.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...     NaN
#
# ...

# %%
print(df_obs.columns)
# Out:
# Index(['YEAR', 'DOY', 'CO2', 'PPT', 'PAR', 'AT', 'ST', 'VPD', 'SW', 'NDEP',
#        ...
#        'CL_herb', 'CFR_herb', 'CFR_lt1mm', 'CFR_1t2mm', 'CLLFALL2', 'SLA',
#        'REPRLIN', 'CLLFALLp', 'CLLFALLh', 'LAD'],
#       dtype='object', length=165)

# %%
df_co2
# Out:
#      year         CO2  co2  site
# 0    2006  355.491179  AMB  PHAC
# 1    2007  360.282307  AMB  PHAC
# 2    2008  361.853206  AMB  PHAC
# 3    2009  364.883917  AMB  PHAC
# 4    2010  366.883818  AMB  PHAC
# ..    ...         ...  ...   ...
# 141  2004  526.355624  ELE  ORNL
# 142  2005  510.803058  ELE  ORNL
# 143  2006  532.386634  ELE  ORNL
# 144  2007  551.067719  ELE  ORNL
# 145  2008  545.435128  ELE  ORNL
#
# [146 rows x 4 columns]

# %% [raw]
# df_obs <- df_obs %>%
#   left_join(df_co2, by=c('site','YEAR','co2'), suffix=c('','.real') ) %>%
#   filter(site=='DUKE'|site=='ORNL')

# %%
df_obs.query("site" == "DUKE" & "site" == "ORNL")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/f1/01gxw8vn74q_x_rf_p5ztryjr405zq/T/ipykernel_73981/1217359509.py in <module>
# ----> 1 df_obs.query("site" == "DUKE" & "site" == "ORNL")
#
# TypeError: unsupported operand type(s) for &: 'str' and 'str'

# %%
df_obs['site'][df_obs['site']=='DUKE' & 'ORNL'] #& df_obs['site'][df_obs['site']=='ORNL']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/f1/01gxw8vn74q_x_rf_p5ztryjr405zq/T/ipykernel_73981/651456537.py in <module>
# ----> 1 df_obs['site'][df_obs['site']=='DUKE' & 'ORNL'] #& df_obs['site'][df_obs['site']=='ORNL']
#
# TypeError: unsupported operand type(s) for &: 'str' and 'str'

# %%
df_obs[(df_obs.site=='DUKE') | (df_obs.site=='ORNL')]
# Out:
#             YEAR  DOY  CO2  PPT  PAR   AT   ST  VPD   SW NDEP  ... CL_herb  \
# rownames                                                       ...
# 1         1998.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...     NaN
# 2         1999.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...     NaN
# 3         2000.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...     NaN
# 4         2001.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...     NaN
# 5         2002.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...     NaN
# 6         2003.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...     NaN
# 7         2004.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...     NaN
# 8         2005.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...     NaN
# 9         2006.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...     NaN
# 10        2007.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...     NaN
# 11        2008.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...     NaN
# ...

# %%
os.getlogin()
# Out:
# 'ud4'
