# %%
import xarray as xr

# %%
import os,glob
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
#import pyreadr # to read .rds files

# %%
path_in = "/Users/ud4/FATESMDS_analysis/outputs/runs/tests_alp/2024/"
Total_EN = 8

# %%
fnames={}

case_id = "Bharat_AW_1PFTallom_r240222_AgBgW_spins_daily_test"
case_id = "Bharat_AW_1PFTallom_r240228_AgBgW_spins_daily"
case_id = "Bharat_1PFTallom_r240313_AgBgW_spins_daily_phen500"
case_id = "Bharat_1PFT_d2bl_r240320d_AgBgW_spins_daily"
case_id = "Bharat_1PFT_d2bl_r240320_EN_AgBgW_spins_d_vcmax"
case_id = "FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD"
sites= ("US-ORN", "US-DUK")
#sites= ("US-ORN",)#, "US-DUK")
#sites= ("US-DUK",)
for en_idx in range(Total_EN):
    for site in sites:
        fnames[f"{case_id}_{site}_spins_en{en_idx+1}"] = f"{path_in}{case_id}_processed/{case_id}_{site}_spins_{'g{:05d}'.format(en_idx+1)}.nc"
    #if site == "US-ORN":
    #    fnames[f"{case_id}_{site}_spins"] = f"{path_in}{case_id}_processed/concatenated_Bharat_H_1PFTallom_r240228_AgBgW_spins_daily_US-ORN_I1850ELMFATES_ad_spinup.nc"

# %%
 fnames
# Out:
# {'FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-ORN_spins_en1': '/Users/ud4/FATESMDS_analysis/outputs/runs/tests_alp/2024/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_processed/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-ORN_spins_g00001.nc',
#  'FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-DUK_spins_en1': '/Users/ud4/FATESMDS_analysis/outputs/runs/tests_alp/2024/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_processed/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-DUK_spins_g00001.nc',
#  'FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-ORN_spins_en2': '/Users/ud4/FATESMDS_analysis/outputs/runs/tests_alp/2024/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_processed/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-ORN_spins_g00002.nc',
#  'FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-DUK_spins_en2': '/Users/ud4/FATESMDS_analysis/outputs/runs/tests_alp/2024/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_processed/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-DUK_spins_g00002.nc',
#  'FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-ORN_spins_en3': '/Users/ud4/FATESMDS_analysis/outputs/runs/tests_alp/2024/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_processed/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-ORN_spins_g00003.nc',
#  'FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-DUK_spins_en3': '/Users/ud4/FATESMDS_analysis/outputs/runs/tests_alp/2024/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_processed/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-DUK_spins_g00003.nc',
#  'FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-ORN_spins_en4': '/Users/ud4/FATESMDS_analysis/outputs/runs/tests_alp/2024/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_processed/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-ORN_spins_g00004.nc',
#  'FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-DUK_spins_en4': '/Users/ud4/FATESMDS_analysis/outputs/runs/tests_alp/2024/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_processed/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-DUK_spins_g00004.nc',
#  'FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-ORN_spins_en5': '/Users/ud4/FATESMDS_analysis/outputs/runs/tests_alp/2024/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_processed/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-ORN_spins_g00005.nc',
#  'FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-DUK_spins_en5': '/Users/ud4/FATESMDS_analysis/outputs/runs/tests_alp/2024/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_processed/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-DUK_spins_g00005.nc',
#  'FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-ORN_spins_en6': '/Users/ud4/FATESMDS_analysis/outputs/runs/tests_alp/2024/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_processed/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-ORN_spins_g00006.nc',
#  'FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-DUK_spins_en6': '/Users/ud4/FATESMDS_analysis/outputs/runs/tests_alp/2024/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_processed/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-DUK_spins_g00006.nc',
#  'FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-ORN_spins_en7': '/Users/ud4/FATESMDS_analysis/outputs/runs/tests_alp/2024/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_processed/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-ORN_spins_g00007.nc',
#  'FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-DUK_spins_en7': '/Users/ud4/FATESMDS_analysis/outputs/runs/tests_alp/2024/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_processed/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-DUK_spins_g00007.nc',
#  'FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-ORN_spins_en8': '/Users/ud4/FATESMDS_analysis/outputs/runs/tests_alp/2024/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_processed/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-ORN_spins_g00008.nc',
#  'FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-DUK_spins_en8': '/Users/ud4/FATESMDS_analysis/outputs/runs/tests_alp/2024/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_processed/FACE_1PFT_minmaxL2fr_r240611b_dL2FR_enVmax_RD_US-DUK_spins_g00008.nc'}

# %%
ds = {}
for idx, key in enumerate(fnames.keys()):
    print (key)
    #ds[key] = xr.open_mfdataset(fnames[key],decode_times=True)
    ds[key] = xr.open_mfdataset(fnames[key])
    ds[key] = xr.open_mfdataset(fnames[key], decode_times=False) # inorder to read the "FATES_DAYSINCE_COLDLEAFOFF". because days are interpreted differeny by xarry
    
    
#for idx, key in enumerate(ds.keys()):
#    ds[key]['time'] =  pd.to_datetime(ds[key].time.values.astype(str))
# Out:
# Bharat_1PFT_d2bl_r240320_EN_AgBgW_spins_d_vcmax_US-ORN_spins_en1
# Bharat_1PFT_d2bl_r240320_EN_AgBgW_spins_d_vcmax_US-DUK_spins_en1
# Bharat_1PFT_d2bl_r240320_EN_AgBgW_spins_d_vcmax_US-ORN_spins_en2
# Bharat_1PFT_d2bl_r240320_EN_AgBgW_spins_d_vcmax_US-DUK_spins_en2
# Bharat_1PFT_d2bl_r240320_EN_AgBgW_spins_d_vcmax_US-ORN_spins_en3
# Bharat_1PFT_d2bl_r240320_EN_AgBgW_spins_d_vcmax_US-DUK_spins_en3
# Bharat_1PFT_d2bl_r240320_EN_AgBgW_spins_d_vcmax_US-ORN_spins_en4
# Bharat_1PFT_d2bl_r240320_EN_AgBgW_spins_d_vcmax_US-DUK_spins_en4
# Bharat_1PFT_d2bl_r240320_EN_AgBgW_spins_d_vcmax_US-ORN_spins_en5
# Bharat_1PFT_d2bl_r240320_EN_AgBgW_spins_d_vcmax_US-DUK_spins_en5
# Bharat_1PFT_d2bl_r240320_EN_AgBgW_spins_d_vcmax_US-ORN_spins_en6
# Bharat_1PFT_d2bl_r240320_EN_AgBgW_spins_d_vcmax_US-DUK_spins_en6
# Bharat_1PFT_d2bl_r240320_EN_AgBgW_spins_d_vcmax_US-ORN_spins_en7
# Bharat_1PFT_d2bl_r240320_EN_AgBgW_spins_d_vcmax_US-DUK_spins_en7
# Bharat_1PFT_d2bl_r240320_EN_AgBgW_spins_d_vcmax_US-ORN_spins_en8
# Bharat_1PFT_d2bl_r240320_EN_AgBgW_spins_d_vcmax_US-DUK_spins_en8
# Bharat_1PFT_d2bl_r240320_EN_AgBgW_spins_d_vcmax_US-ORN_spins_en9
# Bharat_1PFT_d2bl_r240320_EN_AgBgW_spins_d_vcmax_US-DUK_spins_en9
# Bharat_1PFT_d2bl_r240320_EN_AgBgW_spins_d_vcmax_US-ORN_spins_en10
# Bharat_1PFT_d2bl_r240320_EN_AgBgW_spins_d_vcmax_US-DUK_spins_en10

# %%
# How long do you want the simulation plots?
max_r_years = 120

# %%
vars = (
        "BTRAN",
        #"FATES_AUTORESP_USTORY"
       )

for idx, key in enumerate(ds.keys()):
    plt.figure(figsize=(20,6))
    for var in vars:
        try:
            
            plt.plot(ds[key][var], label = var)
            plt.title(f"{ds[key][var].long_name} ({var}) - {key} - AnnualSUM | Units: {ds[key][var].units}")
            #plt.axvline(x = 1982, color = 'r',lw=5, label = 'logging year', alpha=.2)
            plt.axhline(y = 0, color = 'k',lw=2, alpha=.02)
            #plt.axvline(x = 1996, color = 'g',lw=5, label = 'logging year', alpha=.2)
            #plt.xlim(1850,2010)
            #plt.ylim(0,1.1)
            if idx != len(ds.keys())-1 : 
                plt.xticks([])
                plt.xlabel(None)
            print (ds[key][var].long_name )
            plt.legend()
            plt.xlim(0,max_r_years*365)
            for i in range(max_r_years):
                plt.axvline(x = i*365, color = 'k',lw=5, alpha=.02)
                if i%5==0:
                    plt.text(i*365,0, int(i))
        except:
            continue
        
# Remarks:
# Out:
# transpiration beta factor
# transpiration beta factor
# transpiration beta factor
# transpiration beta factor
# transpiration beta factor
# transpiration beta factor
# transpiration beta factor
# transpiration beta factor
# transpiration beta factor
# transpiration beta factor
# transpiration beta factor
# transpiration beta factor
# transpiration beta factor
# transpiration beta factor
# transpiration beta factor
# transpiration beta factor
# transpiration beta factor
# transpiration beta factor
# transpiration beta factor
# transpiration beta factor

# %%
vars = (
        "FATES_TRIMMING",
        #"FATES_AUTORESP_USTORY"
       )

for idx, key in enumerate(ds.keys()):
    plt.figure(figsize=(20,6))
    for var in vars:
        try:
            
            plt.plot(ds[key][var], label = var)
            plt.title(f"{ds[key][var].long_name} ({var}) - {key} - AnnualSUM | Units: {ds[key][var].units}")
            #plt.axvline(x = 1982, color = 'r',lw=5, label = 'logging year', alpha=.2)
            plt.axhline(y = 0, color = 'k',lw=2, alpha=.02)
            #plt.axvline(x = 1996, color = 'g',lw=5, label = 'logging year', alpha=.2)
            #plt.xlim(1850,2010)
            #plt.ylim(0,1.1)
            if idx != len(ds.keys())-1 : 
                plt.xticks([])
                plt.xlabel(None)
            print (ds[key][var].long_name )
            plt.legend()
            plt.xlim(0,max_r_years*365)
            for i in range(max_r_years):
                plt.axvline(x = i*365, color = 'k',lw=5, alpha=.02)
                if i%5==0:
                    plt.text(i*365,0, int(i))
        except:
            continue
        
# Remarks:
# Out:
# degree to which canopy expansion is limited by leaf economics (0-1)
# degree to which canopy expansion is limited by leaf economics (0-1)
# degree to which canopy expansion is limited by leaf economics (0-1)
# degree to which canopy expansion is limited by leaf economics (0-1)
# degree to which canopy expansion is limited by leaf economics (0-1)
# degree to which canopy expansion is limited by leaf economics (0-1)
# degree to which canopy expansion is limited by leaf economics (0-1)
# degree to which canopy expansion is limited by leaf economics (0-1)
# degree to which canopy expansion is limited by leaf economics (0-1)
# degree to which canopy expansion is limited by leaf economics (0-1)
# degree to which canopy expansion is limited by leaf economics (0-1)
# degree to which canopy expansion is limited by leaf economics (0-1)
# degree to which canopy expansion is limited by leaf economics (0-1)
# degree to which canopy expansion is limited by leaf economics (0-1)
# degree to which canopy expansion is limited by leaf economics (0-1)
# degree to which canopy expansion is limited by leaf economics (0-1)
# degree to which canopy expansion is limited by leaf economics (0-1)
# degree to which canopy expansion is limited by leaf economics (0-1)
# degree to which canopy expansion is limited by leaf economics (0-1)
# degree to which canopy expansion is limited by leaf economics (0-1)

# %%
vars = ("FATES_GPP",
        "FATES_NPP",
        "FATES_AUTORESP",
       )


for idx, key in enumerate(ds.keys()):
    plt.figure(figsize=(20,6))
    for var in vars:
        try:
            
            plt.plot(ds[key][var], label = var)
            plt.title(f"{ds[key][var].long_name} ({var}) - {key} - AnnualSUM | Units: {ds[key][var].units}")
            #plt.axvline(x = 1982, color = 'r',lw=5, label = 'logging year', alpha=.2)
            plt.axhline(y = 0, color = 'k',lw=2, alpha=.02)
            #plt.axvline(x = 1996, color = 'g',lw=5, label = 'logging year', alpha=.2)
            #plt.xlim(1850,2010)
            #plt.ylim(0,1.1)
            if idx != len(ds.keys())-1 : 
                plt.xticks([])
                plt.xlabel(None)
            print (ds[key][var].long_name )
            plt.legend()
            plt.xlim(0,max_r_years*365)
            for i in range(max_r_years):
                plt.axvline(x = i*365, color = 'k',lw=5, alpha=.02)
                if i%5==0:
                    plt.text(i*365,0, int(i))
        except:
            continue
        
# Remarks:
# Out:
# gross primary production in kg carbon per m2 per second
# net primary production in kg carbon per m2 per second
# autotrophic respiration in kg carbon per m2 per second
# gross primary production in kg carbon per m2 per second
# net primary production in kg carbon per m2 per second
# autotrophic respiration in kg carbon per m2 per second
# gross primary production in kg carbon per m2 per second
# net primary production in kg carbon per m2 per second
# autotrophic respiration in kg carbon per m2 per second
# gross primary production in kg carbon per m2 per second
# net primary production in kg carbon per m2 per second
# autotrophic respiration in kg carbon per m2 per second
# gross primary production in kg carbon per m2 per second
# net primary production in kg carbon per m2 per second
# autotrophic respiration in kg carbon per m2 per second
# gross primary production in kg carbon per m2 per second
# net primary production in kg carbon per m2 per second
# autotrophic respiration in kg carbon per m2 per second
# gross primary production in kg carbon per m2 per second
# net primary production in kg carbon per m2 per second
# autotrophic respiration in kg carbon per m2 per second
# gross primary production in kg carbon per m2 per second
# net primary production in kg carbon per m2 per second
# autotrophic respiration in kg carbon per m2 per second
# gross primary production in kg carbon per m2 per second
# net primary production in kg carbon per m2 per second
# autotrophic respiration in kg carbon per m2 per second
# gross primary production in kg carbon per m2 per second
# net primary production in kg carbon per m2 per second
# autotrophic respiration in kg carbon per m2 per second
# gross primary production in kg carbon per m2 per second
# net primary production in kg carbon per m2 per second
# autotrophic respiration in kg carbon per m2 per second
# gross primary production in kg carbon per m2 per second
# net primary production in kg carbon per m2 per second
# autotrophic respiration in kg carbon per m2 per second
# gross primary production in kg carbon per m2 per second
# net primary production in kg carbon per m2 per second
# autotrophic respiration in kg carbon per m2 per second
# gross primary production in kg carbon per m2 per second
# net primary production in kg carbon per m2 per second
# autotrophic respiration in kg carbon per m2 per second
# gross primary production in kg carbon per m2 per second
# net primary production in kg carbon per m2 per second
# autotrophic respiration in kg carbon per m2 per second
# gross primary production in kg carbon per m2 per second
# net primary production in kg carbon per m2 per second
# autotrophic respiration in kg carbon per m2 per second
# gross primary production in kg carbon per m2 per second
# net primary production in kg carbon per m2 per second
# autotrophic respiration in kg carbon per m2 per second
# gross primary production in kg carbon per m2 per second
# net primary production in kg carbon per m2 per second
# autotrophic respiration in kg carbon per m2 per second
# gross primary production in kg carbon per m2 per second
# net primary production in kg carbon per m2 per second
# autotrophic respiration in kg carbon per m2 per second
# gross primary production in kg carbon per m2 per second
# net primary production in kg carbon per m2 per second
# autotrophic respiration in kg carbon per m2 per second

# %%
vars = (
        "TLAI",
        #"FATES_AUTORESP_USTORY"
       )
for idx, key in enumerate(ds.keys()):
    plt.figure(figsize=(20,6))
    for var in vars:
        try:
            
            plt.plot(ds[key][var], label = var)
            plt.title(f"{ds[key][var].long_name} ({var}) - {key} - AnnualSUM | Units: {ds[key][var].units}")
            #plt.axvline(x = 1982, color = 'r',lw=5, label = 'logging year', alpha=.2)
            plt.axhline(y = 0, color = 'k',lw=2, alpha=.02)
            #plt.axvline(x = 1996, color = 'g',lw=5, label = 'logging year', alpha=.2)
            #plt.xlim(1850,2010)
            #plt.ylim(0,1.1)
            if idx != len(ds.keys())-1 : 
                plt.xticks([])
                plt.xlabel(None)
            print (ds[key][var].long_name )
            plt.legend()
            plt.xlim(0,max_r_years*365)
            for i in range(max_r_years):
                plt.axvline(x = i*365, color = 'k',lw=5, alpha=.02)
                if i%5==0:
                    plt.text(i*365,0, int(i))
        except:
            continue
        
# Remarks:
# Out:
# total projected leaf area index
# total projected leaf area index
# total projected leaf area index
# total projected leaf area index
# total projected leaf area index
# total projected leaf area index
# total projected leaf area index
# total projected leaf area index
# total projected leaf area index
# total projected leaf area index
# total projected leaf area index
# total projected leaf area index
# total projected leaf area index
# total projected leaf area index
# total projected leaf area index
# total projected leaf area index
# total projected leaf area index
# total projected leaf area index
# total projected leaf area index
# total projected leaf area index

# %%
vars = (
            "FATES_FROOTC",
        "FATES_LEAFC",
        "FATES_STOREC",
    #"FATES_SAPWOODC",
       )


for idx, key in enumerate(ds.keys()):
    plt.figure(figsize=(20,6))
    for var in vars:
        try:
            
            plt.plot(ds[key][var], label = var)
            plt.title(f"{ds[key][var].long_name} ({var}) - {key} - AnnualSUM | Units: {ds[key][var].units}")
            #plt.axvline(x = 1982, color = 'r',lw=5, label = 'logging year', alpha=.2)
            plt.axhline(y = 0, color = 'k',lw=2, alpha=.02)
            #plt.axvline(x = 1996, color = 'g',lw=5, label = 'logging year', alpha=.2)
            #plt.xlim(1850,2010)
            #plt.ylim(0,1.1)
            if idx != len(ds.keys())-1 : 
                plt.xticks([])
                plt.xlabel(None)
            print (ds[key][var].long_name )
            plt.legend()
            plt.xlim(0,max_r_years*365)
            for i in range(max_r_years):
                plt.axvline(x = i*365, color = 'k',lw=5, alpha=.02)
                if i%5==0:
                    plt.text(i*365,0, int(i))
        except:
            continue
        
# Remarks:
# Out:
# total biomass in live plant fine roots in kg carbon per m2
# total biomass in live plant leaves in kg carbon per m2
# total biomass in live plant storage in kg carbon per m2 land area

# %%
vars = ("FATES_DAYSINCE_COLDLEAFOFF",
        "FATES_DAYSINCE_COLDLEAFON",
        #"FATES_AUTORESP_USTORY"
       )


for idx, key in enumerate(ds.keys()):
    plt.figure(figsize=(20,6))
    for var in vars:
        try:
            
            plt.plot(ds[key][var], label = var)
            #plt.title(f"{ds[key][var].long_name} ({var}) - {key} - AnnualSUM | Units: {ds[key][var].units}")
            plt.title(f"{ds[key][var].long_name} ({var}) - {key} - AnnualSUM | Units: days")
            #plt.axvline(x = 1982, color = 'r',lw=5, label = 'logging year', alpha=.2)
            plt.axhline(y = 0, color = 'k',lw=2, alpha=.02)
            #plt.axvline(x = 1996, color = 'g',lw=5, label = 'logging year', alpha=.2)
            #plt.xlim(1850,2010)
            #plt.ylim(0,1.1)
            if idx != len(ds.keys())-1 : 
                plt.xticks([])
                plt.xlabel(None)
            print (ds[key][var].long_name )
            plt.legend()
            plt.xlim(0,max_r_years*365)
            plt.ylim(-10,3500)
            for i in range(max_r_years):
                plt.axvline(x = i*365, color = 'k',lw=5, alpha=.02)
                if i%5==0:
                    plt.text(i*365,0, int(i))
        except:
            continue
        
# Remarks:
# Out:
# site-level days elapsed since cold leaf drop
# site-level days elapsed since cold leaf flush
# site-level days elapsed since cold leaf drop
# site-level days elapsed since cold leaf flush

# %%
vars = ("FATES_DAYSINCE_COLDLEAFOFF",
        "FATES_DAYSINCE_COLDLEAFON",
        #"FATES_AUTORESP_USTORY"
       )


for idx, key in enumerate(ds.keys()):
    plt.figure(figsize=(20,6))
    for var in vars:
        try:
            
            plt.plot(ds[key][var], label = var)
            #plt.title(f"{ds[key][var].long_name} ({var}) - {key} - AnnualSUM | Units: {ds[key][var].units}")
            plt.title(f"{ds[key][var].long_name} ({var}) - {key} - AnnualSUM | Units: days")
            #plt.axvline(x = 1982, color = 'r',lw=5, label = 'logging year', alpha=.2)
            plt.axhline(y = 0, color = 'k',lw=2, alpha=.02)
            #plt.axvline(x = 1996, color = 'g',lw=5, label = 'logging year', alpha=.2)
            #plt.xlim(1850,2010)
            #plt.ylim(0,1.1)
            if idx != len(ds.keys())-1 : 
                plt.xticks([])
                plt.xlabel(None)
            print (ds[key][var].long_name )
            plt.legend()
            #plt.xlim(0,max_r_years*365)
            #plt.ylim(-10,3500)
            for i in range(max_r_years):
                plt.axvline(x = i*365, color = 'k',lw=5, alpha=.02)
                if i%5==0:
                    plt.text(i*365,0, int(i))
        except:
            continue
        
# Remarks:
# Out:
# site-level days elapsed since cold leaf drop
# site-level days elapsed since cold leaf flush
# site-level days elapsed since cold leaf drop
# site-level days elapsed since cold leaf flush

# %%
vars = ("FATES_SAPWOODC",
        "FATES_FROOTC"
       )


for idx, key in enumerate(ds.keys()):
    plt.figure(figsize=(20,6))
    for var in vars:
        try:
            
            plt.plot(ds[key][var], label = var)
            plt.title(f"{ds[key][var].long_name} ({var}) - {key} - AnnualSUM | Units: {ds[key][var].units}")
            #plt.axvline(x = 1982, color = 'r',lw=5, label = 'logging year', alpha=.2)
            plt.axhline(y = 0, color = 'k',lw=2, alpha=.02)
            #plt.axvline(x = 1996, color = 'g',lw=5, label = 'logging year', alpha=.2)
            #plt.xlim(1850,2010)
            #plt.ylim(0,1.1)
            if idx != len(ds.keys())-1 : 
                plt.xticks([])
                plt.xlabel(None)
            print (ds[key][var].long_name )
            plt.legend()
            plt.xlim(0,max_r_years*365)
            for i in range(max_r_years):
                plt.axvline(x = i*365, color = 'k',lw=5, alpha=.02)
                if i%5==0:
                    plt.text(i*365,0, int(i))
        except:
            continue
        
# Remarks:
# Out:
# total biomass in live plant sapwood in kg carbon per m2
# total biomass in live plant fine roots in kg carbon per m2
# total biomass in live plant sapwood in kg carbon per m2
# total biomass in live plant fine roots in kg carbon per m2

# %%
vars = ("MORTALITY_CROWNAREA_CANOPY",
        "MORTALITY_CROWNAREA_UNDERSTORY"
       )

for idx, key in enumerate(ds.keys()):
    plt.figure(figsize=(20,6))
    for var in vars:
        try:
            
            plt.plot(ds[key][var], label = var)
            plt.title(f"{ds[key][var].long_name} ({var}) - {key} - AnnualSUM | Units: {ds[key][var].units}")
            #plt.axvline(x = 1982, color = 'r',lw=5, label = 'logging year', alpha=.2)
            plt.axhline(y = 0, color = 'k',lw=2, alpha=.02)
            #plt.axvline(x = 1996, color = 'g',lw=5, label = 'logging year', alpha=.2)
            #plt.xlim(1850,2010)
            #plt.ylim(0,1.1)
            if idx != len(ds.keys())-1 : 
                plt.xticks([])
                plt.xlabel(None)
            print (ds[key][var].long_name )
            plt.legend()
            plt.xlim(0,max_r_years*365)
            for i in range(max_r_years):
                plt.axvline(x = i*365, color = 'k',lw=5, alpha=.02)
                if i%5==0:
                    plt.text(i*365,0, int(i))
        except:
            continue
        
# Remarks:
# Out:
# Crown area of canopy trees that died
# Crown aera of understory trees that died
# Crown area of canopy trees that died
# Crown aera of understory trees that died

# %%
vars = ("FATES_AUTORESP",
        "FATES_AUTORESP_CANOPY",
        "FATES_AUTORESP_USTORY"
       )


for idx, key in enumerate(ds.keys()):
    plt.figure(figsize=(20,6))
    for var in vars:
        try:
            
            plt.plot(ds[key][var], label = var)
            plt.title(f"{ds[key][var].long_name} ({var}) - {key} - AnnualSUM | Units: {ds[key][var].units}")
            #plt.axvline(x = 1982, color = 'r',lw=5, label = 'logging year', alpha=.2)
            plt.axhline(y = 0, color = 'k',lw=2, alpha=.02)
            #plt.axvline(x = 1996, color = 'g',lw=5, label = 'logging year', alpha=.2)
            #plt.xlim(1850,2010)
            #plt.ylim(0,1.1)
            if idx != len(ds.keys())-1 : 
                plt.xticks([])
                plt.xlabel(None)
            print (ds[key][var].long_name )
            plt.legend()
            plt.xlim(0,max_r_years*365)
            for i in range(max_r_years):
                plt.axvline(x = i*365, color = 'k',lw=5, alpha=.02)
                if i%5==0:
                    plt.text(i*365,0, int(i))
        except:
            continue
        
# Remarks:
# Out:
# autotrophic respiration in kg carbon per m2 per second
# autotrophic respiration of canopy plants in kg carbon per m2 per second
# autotrophic respiration of understory plants in kg carbon per m2 per second
# autotrophic respiration in kg carbon per m2 per second
# autotrophic respiration of canopy plants in kg carbon per m2 per second
# autotrophic respiration of understory plants in kg carbon per m2 per second

# %%
vars = ("FATES_CANOPY_VEGC",
        #"FATES_AUTORESP_CANOPY",
        #"FATES_AUTORESP_USTORY"
       )

for idx, key in enumerate(ds.keys()):
    plt.figure(figsize=(20,6))
    for var in vars:
        try:
            
            plt.plot(ds[key][var], label = var)
            plt.title(f"{ds[key][var].long_name} ({var}) - {key} - AnnualSUM | Units: {ds[key][var].units}")
            #plt.axvline(x = 1982, color = 'r',lw=5, label = 'logging year', alpha=.2)
            plt.axhline(y = 0, color = 'k',lw=2, alpha=.02)
            #plt.axvline(x = 1996, color = 'g',lw=5, label = 'logging year', alpha=.2)
            #plt.xlim(1850,2010)
            #plt.ylim(0,1.1)
            if idx != len(ds.keys())-1 : 
                plt.xticks([])
                plt.xlabel(None)
            print (ds[key][var].long_name )
            plt.legend()
            plt.xlim(0,max_r_years*365)
            for i in range(max_r_years):
                plt.axvline(x = i*365, color = 'k',lw=5, alpha=.02)
                if i%5==0:
                    plt.text(i*365,0, int(i))
        except:
            continue
        
# Remarks:
# Out:
# biomass of canopy plants in kg carbon per m2 land area
# biomass of canopy plants in kg carbon per m2 land area

# %%
vars = ("FATES_TVEG",
        "FATES_TVEG24",
        #"FATES_AUTORESP_USTORY"
       )


for idx, key in enumerate(ds.keys()):
    plt.figure(figsize=(20,6))
    for var in vars:
        try:
            
            plt.plot(ds[key][var], label = var)
            plt.title(f"{ds[key][var].long_name} ({var}) - {key} - AnnualSUM | Units: {ds[key][var].units}")
            #plt.axvline(x = 1982, color = 'r',lw=5, label = 'logging year', alpha=.2)
            plt.axhline(y = 0, color = 'k',lw=2, alpha=.02)
            #plt.axvline(x = 1996, color = 'g',lw=5, label = 'logging year', alpha=.2)
            #plt.xlim(1850,2010)
            #plt.ylim(0,1.1)
            if idx != len(ds.keys())-1 : 
                plt.xticks([])
                plt.xlabel(None)
            print (ds[key][var].long_name )
            plt.legend()
            plt.xlim(0,max_r_years*365)
            for i in range(max_r_years):
                plt.axvline(x = i*365, color = 'k',lw=5, alpha=.02)
                if i%5==0:
                    plt.text(i*365,0, int(i))
        except:
            continue
        
# Remarks:
# Out:
# fates instantaneous mean vegetation temperature by site
# fates 24-hr running mean vegetation temperature by site
# fates instantaneous mean vegetation temperature by site
# fates 24-hr running mean vegetation temperature by site

# %%
ds[key][var]
# Out:
# <xarray.DataArray 'FATES_TVEG24' (time: 40150, lndgrid: 1)>
# dask.array<open_dataset-809a5ecbffa2d9bfb4bb0e1560493887FATES_TVEG24, shape=(40150, 1), dtype=float32, chunksize=(40150, 1), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) float64 0.0 1.0 2.0 3.0 ... 4.015e+04 4.015e+04 4.015e+04
# Dimensions without coordinates: lndgrid
# Attributes:
#     units:      degree_Celsius
#     long_name:  fates 24-hr running mean vegetation temperature by site

# %%
vars = ("FATES_AUTORESP",
        "FATES_AUTORESP_CANOPY",
        "FATES_GROWTH_RESP",
       )


for idx, key in enumerate(ds.keys()):
    plt.figure(figsize=(20,6))
    for var in vars:
        try:
            
            plt.plot(ds[key][var], label = var)
            plt.title(f"{ds[key][var].long_name} ({var}) - {key} - AnnualSUM | Units: {ds[key][var].units}")
            #plt.axvline(x = 1982, color = 'r',lw=5, label = 'logging year', alpha=.2)
            plt.axhline(y = 0, color = 'k',lw=2, alpha=.02)
            #plt.axvline(x = 1996, color = 'g',lw=5, label = 'logging year', alpha=.2)
            #plt.xlim(1850,2010)
            #plt.ylim(0,1.1)
            if idx != len(ds.keys())-1 : 
                plt.xticks([])
                plt.xlabel(None)
            print (ds[key][var].long_name )
            plt.legend()
            plt.xlim(0,max_r_years*365)
            for i in range(max_r_years):
                plt.axvline(x = i*365, color = 'k',lw=5, alpha=.02)
                if i%5==0:
                    plt.text(i*365,0, int(i))
        except:
            continue     
# Remarks:
# Out:
# autotrophic respiration in kg carbon per m2 per second
# autotrophic respiration of canopy plants in kg carbon per m2 per second
# growth respiration in kg carbon per m2 per second
# autotrophic respiration in kg carbon per m2 per second
# autotrophic respiration of canopy plants in kg carbon per m2 per second
# growth respiration in kg carbon per m2 per second

# %%
vars = ("FATES_NONSTRUCTC",
        "FATES_STRUCTC",
        #"FATES_GROWTH_RESP",
       )


for idx, key in enumerate(ds.keys()):
    plt.figure(figsize=(20,6))
    for var in vars:
        try:
            
            plt.plot(ds[key][var], label = var)
            plt.title(f"{ds[key][var].long_name} ({var}) - {key} - AnnualSUM | Units: {ds[key][var].units}")
            #plt.axvline(x = 1982, color = 'r',lw=5, label = 'logging year', alpha=.2)
            plt.axhline(y = 0, color = 'k',lw=2, alpha=.02)
            #plt.axvline(x = 1996, color = 'g',lw=5, label = 'logging year', alpha=.2)
            #plt.xlim(1850,2010)
            #plt.ylim(0,1.1)
            if idx != len(ds.keys())-1 : 
                plt.xticks([])
                plt.xlabel(None)
            print (ds[key][var].long_name )
            plt.legend()
            plt.xlim(0,max_r_years*365)
            for i in range(max_r_years):
                plt.axvline(x = i*365, color = 'k',lw=5, alpha=.02)
                if i%5==0:
                    plt.text(i*365,0, int(i))
        except:
            continue
        
# Remarks:
# Out:
# non-structural biomass (sapwood + leaf + fineroot) in kg carbon per m2
# structural biomass in kg carbon per m2 land area
# non-structural biomass (sapwood + leaf + fineroot) in kg carbon per m2
# structural biomass in kg carbon per m2 land area

# %%
vars = (
    #"FATES_SAPWOODC",
        "FATES_FROOTC",
        "FATES_LEAFC",
        "FATES_STOREC",
        #"FATES_AUTORESP_USTORY"
       )

for idx, key in enumerate(ds.keys()):
    plt.figure(figsize=(20,6))
    for var in vars:
        try:
            if var == "FATES_FROOTC":
                plt.plot(ds[key][var], label = var, color='r', marker='+')
            else:
                pass
                plt.plot(ds[key][var], label = var)
            plt.title(f"{ds[key][var].long_name} ({var}) - {key} - AnnualSUM | Units: {ds[key][var].units}")
            #plt.axvline(x = 1982, color = 'r',lw=5, label = 'logging year', alpha=.2)
            plt.axhline(y = 0, color = 'k',lw=2, alpha=.2)

            #plt.axvline(x = 1996, color = 'g',lw=5, label = 'logging year', alpha=.2)
            #plt.xlim(1850,2010)
            #plt.ylim(0,1.1)
            if idx != len(ds.keys())-1 : 
                plt.xticks([])
                plt.xlabel(None)
            print (ds[key][var].long_name )
            plt.legend()
            plt.xlim(0,30*365)
        except:
            continue
    

        
# Remarks:
# Out:
# total biomass in live plant fine roots in kg carbon per m2
# total biomass in live plant leaves in kg carbon per m2
# total biomass in live plant storage in kg carbon per m2 land area
# total biomass in live plant fine roots in kg carbon per m2
# total biomass in live plant leaves in kg carbon per m2
# total biomass in live plant storage in kg carbon per m2 land area
