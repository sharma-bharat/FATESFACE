# %% [markdown]
# # Aim : to create the file that OLMT can read to create ensembles

# %%
pwd
# Out:
# '/Users/ud4/repos/GitHub/FATESFACE/Jupyter_Notebooks'

# %%
import pandas as pd
import itertools
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# !ls -ltr tmp
# Out:
# total 12184
# -rw-r--r--@ 1 ud4  ORNL\Domain Users   15061 Sep 18 12:55 obs_a.csv
# -rw-r--r--@ 1 ud4  ORNL\Domain Users    9835 Sep 18 14:05 r20240914e_RD.xlsx
# -rw-r--r--@ 1 ud4  ORNL\Domain Users    9865 Sep 18 21:36 r240914e_RD.xlsx
# -rw-r--r--@ 1 ud4  ORNL\Domain Users    9885 Sep 18 21:37 r240914d_RD.xlsx
# -rw-r--r--@ 1 ud4  ORNL\Domain Users    9861 Sep 18 22:03 r240914c_RD.xlsx
# -rw-r--r--@ 1 ud4  ORNL\Domain Users    9878 Sep 18 22:04 r240914b_RD.xlsx
# -rw-r--r--@ 1 ud4  ORNL\Domain Users    9885 Sep 18 22:05 r240913_RD.xlsx
# -rw-r--r--@ 1 ud4  ORNL\Domain Users    9870 Sep 18 22:23 r240914a_RD.xlsx
# -rw-r--r--@ 1 ud4  ORNL\Domain Users    9864 Sep 19 12:02 r240914e_ECA.xlsx
# -rw-r--r--@ 1 ud4  ORNL\Domain Users    9814 Sep 19 12:02 r240913_ECA.xlsx
# -rw-r--r--@ 1 ud4  ORNL\Domain Users    9826 Sep 19 12:02 r240914a_ECA.xlsx
# -rw-r--r--@ 1 ud4  ORNL\Domain Users    9813 Sep 19 12:02 r240914b_ECA.xlsx
# -rw-r--r--@ 1 ud4  ORNL\Domain Users    9825 Sep 19 12:03 r240914c_ECA.xlsx
# -rw-r--r--@ 1 ud4  ORNL\Domain Users    9838 Sep 19 12:03 r240914d_ECA.xlsx
# -rw-r--r--  1 ud4  ORNL\Domain Users     646 Dec 19 15:10 AMB_DUKE.csv
# -rw-r--r--  1 ud4  ORNL\Domain Users     646 Dec 19 15:12 AMB_DUKE_AX.csv
# -rw-r--r--  1 ud4  ORNL\Domain Users     680 Dec 19 15:12 AMB_DUKE_ASE.csv
# -rw-r--r--@ 1 ud4  ORNL\Domain Users   41509 Dec 19 23:17 FinalRD_Calibration_Ranges.xlsx
# -rw-r--r--@ 1 ud4  ORNL\Domain Users  263022 Dec 19 23:19 combinations_RD.csv
# -rw-r--r--@ 1 ud4  ORNL\Domain Users     378 Dec 20 10:39 MinMaxMedianRD.csv
# -rw-r--r--@ 1 ud4  ORNL\Domain Users   34361 Dec 20 11:05 bs_calibration_parm_vals
# -rw-r--r--@ 1 ud4  ORNL\Domain Users     772 Jan  7 18:33 ELE_DUKE_AX.csv
# -rw-r--r--@ 1 ud4  ORNL\Domain Users     771 Jan  7 18:40 ELE_DUKE_ASE.csv
# -rw-r--r--@ 1 ud4  ORNL\Domain Users     702 Jan  7 18:42 AMB_ORNL_ASE.csv
# -rw-r--r--@ 1 ud4  ORNL\Domain Users     534 Jan  7 19:01 ELE_ORNL_ASE.csv
# -rw-r--r--@ 1 ud4  ORNL\Domain Users     569 Jan  7 21:40 ELE_ORNL_AX.csv
# -rw-r--r--@ 1 ud4  ORNL\Domain Users     680 Jan  7 21:40 AMB_ORNL_AX.csv
# -rw-r--r--  1 ud4  ORNL\Domain Users     388 Jan  9 23:32 save_txt.py
# -rw-r--r--@ 1 ud4  ORNL\Domain Users   37941 Jan 10 00:07 FinalRD_Calibration_Ranges_ORNL.xlsx
# -rw-r--r--@ 1 ud4  ORNL\Domain Users   38121 Jan 14 20:36 FinalRD_Calibration_Ranges_ORNL2.xlsx
# -rw-r--r--  1 ud4  ORNL\Domain Users  372518 Jan 14 20:37 combinations_RD_ORNL.csv
# -rw-r--r--  1 ud4  ORNL\Domain Users  372518 Jan 14 20:37 combinations_RD_ORNL
# -rw-r--r--  1 ud4  ORNL\Domain Users  372518 Jan 14 20:44 combinations_RD_ORNL2.csv
# -rw-r--r--  1 ud4  ORNL\Domain Users  372518 Jan 14 20:44 combinations_RD_ORNL2
# -rw-r--r--  1 ud4  ORNL\Domain Users  372603 Jan 17 16:49 combinations_RD_ORNL_20250117.csv
# -rw-r--r--  1 ud4  ORNL\Domain Users  372518 Jan 21 20:28 combinations_RD_3.csv
# -rw-r--r--  1 ud4  ORNL\Domain Users  372345 Jan 21 20:28 combinations_RD_3
# -rw-r--r--  1 ud4  ORNL\Domain Users  372603 Jan 23 23:31 combinations_RD_4.csv
# -rw-r--r--  1 ud4  ORNL\Domain Users  372430 Jan 23 23:31 combinations_RD_4
# -rw-r--r--@ 1 ud4  ORNL\Domain Users   34668 Jan 25 20:34 RD_nonlog.xlsx
# -rw-r--r--  1 ud4  ORNL\Domain Users  371875 Jan 25 20:37 combinations_RD_5
# -rw-r--r--@ 1 ud4  ORNL\Domain Users   37716 Feb  6 09:58 RD_nonlog_revised.xlsx
# -rw-r--r--@ 1 ud4  ORNL\Domain Users  372895 Feb  6 10:02 combinations_RD_revised
# -rw-r--r--@ 1 ud4  ORNL\Domain Users  372895 Feb  6 10:02 combinations_RD_revised.csv
# -rw-r--r--@ 1 ud4  ORNL\Domain Users  167139 Feb  6 10:39 RD_nonlog_revised2.xlsx
# -rw-r--r--  1 ud4  ORNL\Domain Users  373452 Feb  6 10:43 combinations_RD_revised2
# -rw-r--r--  1 ud4  ORNL\Domain Users  373452 Feb  6 10:43 combinations_RD_revised2.csv
# -rw-r--r--@ 1 ud4  ORNL\Domain Users  101265 Feb  7 14:49 ECA_nonlog_revised3.xlsx

# %%
# !open .

# %%
# Load the Excel file
#excel_file = 'tmp/FinalRD_Calibration_Ranges.xlsx'
excel_file = 'tmp/FinalRD_Calibration_Ranges_ORNL2.xlsx'
excel_file = 'tmp/FinalRD_Calibration_Ranges_ORNL.xlsx'
excel_file = 'tmp/RD_nonlog.xlsx'
excel_file = 'tmp/RD_nonlog_revised.xlsx'
excel_file = 'tmp/RD_nonlog_revised2.xlsx'
excel_file = 'tmp/ECA_nonlog_revised3.xlsx'

# %%
df = pd.read_excel(excel_file)

# Display the data
print(df)
# Out:
#       fates_allom_d2bl1  fates_maintresp_leaf_ryan1991_baserate  \
# 0               0.02000                            1.000000e-07
# 1               0.02012                            1.059373e-07
# 2               0.02024                            1.118746e-07
# 3               0.02036                            1.178119e-07
# 4               0.02048                            1.237492e-07
# ...                 ...                                     ...
# 1495            0.19952                            8.976251e-06
# 1496            0.19964                            8.982188e-06
# 1497            0.19976                            8.988125e-06
# 1498            0.19988                            8.994063e-06
# 1499            0.20000                            9.000000e-06
#
#       fates_maintresp_nonleaf_baserate  fates_cnp_store_ovrflw_frac  \
# 0                         1.000000e-07                     4.000000
# 1                         1.026017e-07                     4.006671
# 2                         1.052035e-07                     4.013342
# 3                         1.078052e-07                     4.020013
# 4                         1.104069e-07                     4.026684
# ...                                ...                          ...
# 1495                      3.989593e-06                    13.973316
# 1496                      3.992195e-06                    13.979987
# 1497                      3.994797e-06                    13.986658
# 1498                      3.997398e-06                    13.993329
# 1499                      4.000000e-06                    14.000000
#
#       fates_cnp_vmax_nh4
# 0           8.500000e-07
# 1           8.694463e-07
# 2           8.888926e-07
# 3           9.083389e-07
# 4           9.277852e-07
# ...                  ...
# 1495        2.992221e-05
# 1496        2.994166e-05
# 1497        2.996111e-05
# 1498        2.998055e-05
# 1499        3.000000e-05
#
# [1500 rows x 5 columns]

# %%
df.head()
# Out:
#    fates_allom_d2bl1  fates_maintresp_leaf_ryan1991_baserate  \
# 0            0.02000                            1.000000e-07
# 1            0.02012                            1.059373e-07
# 2            0.02024                            1.118746e-07
# 3            0.02036                            1.178119e-07
# 4            0.02048                            1.237492e-07
#
#    fates_maintresp_nonleaf_baserate  fates_cnp_store_ovrflw_frac  \
# 0                      1.000000e-07                     4.000000
# 1                      1.026017e-07                     4.006671
# 2                      1.052035e-07                     4.013342
# 3                      1.078052e-07                     4.020013
# 4                      1.104069e-07                     4.026684
#
#    fates_cnp_vmax_nh4
# 0        8.500000e-07
# 1        8.694463e-07
# 2        8.888926e-07
# 3        9.083389e-07
# 4        9.277852e-07

# %%
# Create a pair plot
sns.pairplot(df)

# Add a title
plt.suptitle("Pairwise Correlations", y=1.02)

# Save the plot
#plt.savefig("pairwise_correlations.png")

# Show the plot
plt.show()

# %%
Total_samples_needed = 1500
print (Total_samples_needed//df.shape[0])
random_combinations = df.head(0).copy (deep = True)
# Randomizing one col at a time
for i in range(Total_samples_needed//df.shape[0]):
    for idx in range (5):
        df[df.columns[idx]] = df[df.columns[idx]].sample(frac=1).reset_index(drop=True)
    random_combinations = random_combinations.append(df)
random_combinations.reset_index(inplace=True,drop=True)
# Out:
# 1

# %%
# Create a pair plot
sns.pairplot(random_combinations)

# Add a title
plt.suptitle("Pairwise Correlations", y=1.02)

# Save the plot
#plt.savefig("pairwise_correlations.png")

# Show the plot
plt.show()

# Calculate the correlation matrix
correlation_matrix = random_combinations.corr()

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")

# Save the heatmap
#plt.savefig("correlation_heatmap.png")

# Show the plot
plt.show()

# %%
random_combinations_log = random_combinations.copy(deep=True)
random_combinations_log['log_fates_cnp_vmax_nh4'] = np.log10(random_combinations_log['fates_cnp_vmax_nh4'])
random_combinations_log = random_combinations_log.drop('fates_cnp_vmax_nh4', axis=1)

# %%
# Create a pair plot
sns.pairplot(random_combinations_log)

# Add a title
plt.suptitle("Pairwise Correlations", y=1.02)

# Save the plot
#plt.savefig("pairwise_correlations.png")

# Show the plot
plt.show()


# Calculate the correlation matrix
correlation_matrix = random_combinations_log.corr()

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")

# Save the heatmap
#plt.savefig("correlation_heatmap.png")

# Show the plot
plt.show()

# %%
random_combinations
# Out:
#       fates_allom_d2bl1  fates_maintresp_leaf_ryan1991_baserate  \
# 0              0.145604                                0.000009
# 1              0.167218                                0.000004
# 2              0.174543                                0.000002
# 3              0.061788                                0.000005
# 4              0.118706                                0.000004
# ...                 ...                                     ...
# 1495           0.163856                                0.000001
# 1496           0.170460                                0.000002
# 1497           0.096011                                0.000003
# 1498           0.141401                                0.000007
# 1499           0.063349                                0.000009
#
#       fates_maintresp_nonleaf_baserate  fates_cnp_store_ovrflw_frac  \
# 0                         1.343629e-06                     5.961308
# 1                         4.746498e-07                     8.616411
# 2                         3.461441e-06                     8.969980
# 3                         3.706004e-06                     7.222148
# 4                         3.747632e-06                    12.078719
# ...                                ...                          ...
# 1495                      1.109473e-06                     7.475650
# 1496                      2.012275e-06                    11.398266
# 1497                      1.850967e-06                    13.172782
# 1498                      2.475384e-06                     4.146765
# 1499                      2.847432e-06                     8.883256
#
#       fates_cnp_vmax_nh4
# 0               0.000022
# 1               0.000011
# 2               0.000023
# 3               0.000020
# 4               0.000029
# ...                  ...
# 1495            0.000009
# 1496            0.000029
# 1497            0.000008
# 1498            0.000023
# 1499            0.000003
#
# [1500 rows x 5 columns]

# %%
df_comb = pd.DataFrame(random_combinations, columns=df.columns)
df_comb["fates_cnp_vmax_no3"] = df_comb["fates_cnp_vmax_nh4"]
df_comb["fates_cnp_vmax_p"] = df_comb["fates_cnp_vmax_nh4"]/10

# %%
#df_comb.to_csv(f'tmp/combinations_RD_4.csv', index=False)
#df_comb.to_csv(f'tmp/combinations_RD_4', sep= ' ',  index=False,header=False )

#df_comb.to_csv(f'tmp/combinations_RD_revised2', sep= ' ',  index=False,header=False ) # non-log transform
#df_comb.to_csv(f'tmp/combinations_RD_revised2.csv', sep= ',',  index=False,header=False ) # non-log transform

#ECA
df_comb.to_csv(f'tmp/combinations_ECA_revised3', sep= ' ',  index=False,header=False ) # non-log transform
df_comb.to_csv(f'tmp/combinations_ECA_revised3.csv', sep= ',',  index=False,header=False ) # non-log transform

# %%
df_comb
# Out:
#       fates_allom_d2bl1  fates_maintresp_leaf_ryan1991_baserate  \
# 0              0.145604                                0.000009
# 1              0.167218                                0.000004
# 2              0.174543                                0.000002
# 3              0.061788                                0.000005
# 4              0.118706                                0.000004
# ...                 ...                                     ...
# 1495           0.163856                                0.000001
# 1496           0.170460                                0.000002
# 1497           0.096011                                0.000003
# 1498           0.141401                                0.000007
# 1499           0.063349                                0.000009
#
#       fates_maintresp_nonleaf_baserate  fates_cnp_store_ovrflw_frac  \
# 0                         1.343629e-06                     5.961308
# 1                         4.746498e-07                     8.616411
# 2                         3.461441e-06                     8.969980
# 3                         3.706004e-06                     7.222148
# 4                         3.747632e-06                    12.078719
# ...                                ...                          ...
# 1495                      1.109473e-06                     7.475650
# 1496                      2.012275e-06                    11.398266
# 1497                      1.850967e-06                    13.172782
# 1498                      2.475384e-06                     4.146765
# 1499                      2.847432e-06                     8.883256
#
#       fates_cnp_vmax_nh4  fates_cnp_vmax_no3  fates_cnp_vmax_p
# 0               0.000022            0.000022      2.159920e-06
# 1               0.000011            0.000011      1.135100e-06
# 2               0.000023            0.000023      2.327158e-06
# 3               0.000020            0.000020      2.017962e-06
# 4               0.000029            0.000029      2.929993e-06
# ...                  ...                 ...               ...
# 1495            0.000009            0.000009      8.881321e-07
# 1496            0.000029            0.000029      2.863876e-06
# 1497            0.000008            0.000008      7.889560e-07
# 1498            0.000023            0.000023      2.261041e-06
# 1499            0.000003            0.000003      2.716845e-07
#
# [1500 rows x 7 columns]

# %%
random_combinations.min()
# Out:
# fates_allom_d2bl1                         2.000000e-02
# fates_maintresp_leaf_ryan1991_baserate    1.000000e-07
# fates_maintresp_nonleaf_baserate          1.000000e-07
# fates_cnp_store_ovrflw_frac               4.000000e+00
# fates_cnp_vmax_nh4                        8.500000e-07
# dtype: float64

# %%
random_combinations.max()
# Out:
# fates_allom_d2bl1                         2.000000e-01
# fates_maintresp_leaf_ryan1991_baserate    9.000000e-06
# fates_maintresp_nonleaf_baserate          4.000000e-06
# fates_cnp_store_ovrflw_frac               1.400000e+01
# fates_cnp_vmax_nh4                        9.000000e-07
# dtype: float64

# %% [raw]
# !scp tmp/combinations_ECA_revised3 ud4@opendtn.ccs.ornl.gov:/ccsopen/home/ud4/models/OLMT/data/lnd/clm2/paramdata/ensemble/.

# %% [raw]
# scp tmp/combinations_ECA_revised3 ud4@opendtn.ccs.ornl.gov:/gpfs/wolf2/cades/cli185/scratch/ud4
